# %% [markdown]
# <a href="https://colab.research.google.com/github/Harikrishnan0708/sripi/blob/main/ex_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 . Types of Variables Question: Write a Python program that defines three types of variables: A string variable to store your name. An integer variable to store your age. A float variable to store your height in meters. Print these variables along with their types using the type() function.

# %%
name='harikrishnan'
age=23
height=182.56
print('name',type(name))
print('age',type(age))
print('height',type(height))
# Out:
# name <class 'str'>
# age <class 'int'>
# height <class 'float'>

# %% [markdown]
# Lists Question: Create a list of five fruits (["apple", "banana", "cherry", "date", "elderberry"]): a) Print the first and last fruit from the list. b) Add a new fruit to the end of the list. c) Remove the second fruit from the list. d) Sort the list in alphabetical order and print it.

# %%
fruits=['apple','banana','orange','strawbwerry','cherry']
print(fruits[0])
print(fruits[4])
fruits.append('guava')
print(fruits)
fruits.pop(1)
fruits.sort()
print(fruits)
# Out:
# apple
# cherry
# ['apple', 'banana', 'orange', 'strawbwerry', 'cherry', 'guava']
# ['apple', 'cherry', 'guava', 'orange', 'strawbwerry']

# %% [markdown]
# 3 . Tuples Question: Create a tuple to store the names of three programming languages ("Python", "Java", "C++"): a) Access the second language in the tuple. b) Try to replace the second language with "JavaScript". What happens? c) Convert the tuple to a list, make the modification, and convert it back to a tuple.

# %%
prog_lang=('java','python','c')
print(prog_lang[1])
list_lang=list(prog_lang)
list_lang[0]='javascript'
print(list_lang)
list_lang2=tuple(list_lang)
print(list_lang2)
# Out:
# python
# ['javascript', 'python', 'c']
# ('javascript', 'python', 'c')

# %% [markdown]
# 4. Data Dictionary - Basics Question: Create a dictionary with the following student details: name: "John" age: 18 grade: "A" a) Access and print the value of grade. b) Add a new key-value pair for hobby with the value "reading". c) Delete the age key from the dictionary.

# %%
student_details={"name":"john","age":18,"grade":"A"}
print(student_details)
print(student_details["grade"])
student_details["hobby"]="reading"
print(student_details)
student_details.pop("age")
print(student_details)
# Out:
# {'name': 'john', 'age': 18, 'grade': 'A'}
# A
# {'name': 'john', 'age': 18, 'grade': 'A', 'hobby': 'reading'}
# {'name': 'john', 'grade': 'A', 'hobby': 'reading'}

# %% [markdown]
# 5 . Data Dictionary - Operations Question: You are given the following dictionary: marks = {"Math": 85, "Science": 90, "English": 78} a) Find the average marks across all subjects. b) Update the marks for Math to 88. c) Check if the key "History" exists in the dictionary.

# %%
marks = {"Math": 85, "Science": 90, "English": 78}
avg=sum(marks.values())/len(marks)
print(avg)
marks["Math"]=88
print(marks)
print("History" in marks)
# Out:
# 84.33333333333333
# {'Math': 88, 'Science': 90, 'English': 78}
# False

# %% [markdown]
# 6 .
# Functions - Basics Question: Write a Python function named square that takes an integer as input and returns its square. Call the function with the value 7 and print the result.

# %%
def square(n):
  sq_n=n*n
  return sq_n
n=int(input())
sq_no=square(n)
print(sq_no)
# Out:
# 4
# 16

# %% [markdown]
# 7. Functions - Default Arguments Question: Write a Python function named greet that takes two parameters: name (a string) message (a string with a default value of "Welcome!") Call the function twice:
# *Once by providing both name and message. *Once by providing only name

# %%
def greet(name,message="welcome"):
  print(message,name)
greet("gowtham","hello")
greet("gowtham")
# Out:
# hello gowtham
# welcome gowtham

# %% [markdown]
# 8. Functions - Positional and Keyword Arguments Question: Write a Python function named student_info that accepts the following parameters: name (string) age (integer) grade (string, default value is "A") Call the function with:
# *Positional arguments only. *Keyword arguments only. Print the result in each case.

# %%
def student_info(name,age,grade="A"):
  return name,age,grade
print(student_info("gowtham",22,))
print(student_info(name="rahul",age="24",grade="C"))
# Out:
# ('gowtham', 22, 'A')
# ('rahul', '24', 'C')

# %% [markdown]
# 9. Lists and Functions Question: Write a Python program with the following requirements: a) Create a list of numbers: [10, 20, 30, 40, 50]. b) Define a function named double_values that takes a list as input and returns a new list with each value doubled. c) Pass the list to the function and print the returned list.

# %%
list_num=[10,20,30,40,50]
def doubled_values(lst):
  double=[]
  for i in lst:
    lst=i*2
    double.append(lst)
  return double
print(doubled_values(list_num))
# Out:
# [20, 40, 60, 80, 100]
